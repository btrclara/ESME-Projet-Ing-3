# %%
import pandas as pd
import numpy as np

# Load the dataset
path = 'dataset.csv'
col_name = ['ax', 'ay', 'az', 'gx', 'gy', 'gz','flex1', 'flex2', 'flex3', 'flex4', 'flex5', 'duree', 'class']
dataset = pd.read_csv(path, names=col_name)
#dataset = dataset.drop(columns =['date', 'time'])
dataset = dataset.drop(columns =['duree'])
dataset.head()
# Out:
#      ax    ay    az  gx  gy  gz  flex1  flex2  flex3  flex4  flex5 class
# 0 -0.41  0.24  0.78  16  28  18    454    733    658    687    693     B
# 1 -0.50  0.22  1.04  12 -31   0    451    713    679    664    713     B
# 2 -0.42  0.16  0.99  -6   6   9    452    719    671    681    696     B
# 3 -0.40  0.17  0.98   0   6   4    456    740    656    679    697     B
# 4 -0.45  0.17  0.96  -3   2   0    457    728    685    673    720     B

# %%
df_grouped = dataset.groupby(dataset.index // 5).agg({
    "ax": [("ax_mean", "mean"), ("ax_std", "std")], 
    "ay": [("ay_mean", "mean"), ("ay_std", "std")], 
    "az": [("az_mean", "mean"), ("az_std", "std")], 
    "gx": [("gx_mean", "mean"), ("gx_std", "std")],
    "gy": [("gy_mean", "mean"), ("gy_std", "std")],
    "gz": [("gz_mean", "mean"), ("gz_std", "std")],
    "flex1": [("flex1_mean", "mean"), ("flex1_std", "std")],
    "flex2": [("flex2_mean", "mean"), ("flex2_std", "std")],
    "flex3": [("flex3_mean", "mean"), ("flex3_std", "std")],
    "flex4": [("flex4_mean", "mean"), ("flex4_std", "std")],
    "flex5": [("flex5_mean", "mean"), ("flex5_std", "std")],
    "class": [("class", "first")],})

df_grouped.columns = df_grouped.columns.map('_'.join)

#df_grouped = df_grouped.drop(labels=0, axis=0)
df_grouped.shape
df_grouped.head()
display(df_grouped)
# Out:
#     ax_ax_mean  ax_ax_std  ay_ay_mean  ay_ay_std  az_az_mean  az_az_std  \
# 0       -0.436   0.040373       0.192   0.035637       0.950   0.099499
# 1       -0.454   0.005477       0.240   0.007071       0.942   0.008367
# 2       -0.418   0.020494       0.356   0.008944       0.922   0.016432
# 3       -0.438   0.010954       0.134   0.011402       0.976   0.005477
# 4       -0.430   0.000000       0.150   0.012247       0.980   0.000000
# ..         ...        ...         ...        ...         ...        ...
# 61       0.602   0.266402      -0.122   0.161152       0.888   0.197028
# 62       0.630   0.183439       0.062   0.215453       0.816   0.139392
# 63       0.604   0.190735      -0.160   0.133229       0.860   0.118110
# 64       0.592   0.251237      -0.090   0.102956       0.918   0.121943
# 65       0.604   0.235436      -0.022   0.148560       0.864   0.134462
#
#     gx_gx_mean  gx_gx_std  gy_gy_mean  gy_gy_std  ...  flex1_flex1_std  \
# 0          3.8   9.654015         2.2  21.194339  ...         2.549510
# 1         -1.2   0.447214         3.0   0.000000  ...         5.449771
# 2         -1.6   1.516575         2.6   1.516575  ...         2.302173
# 3         -1.6   0.547723         3.2   1.095445  ...         3.033150
# 4         -1.8   0.447214         2.8   0.447214  ...         7.733046
# ..         ...        ...         ...        ...  ...              ...
# 61         3.4  12.340989         8.4   9.555103  ...        13.553597
# 62         7.0   9.669540        -7.4  18.420098  ...        53.714989
# 63         2.4  11.126545        -2.4  17.372392  ...        51.752295
# 64         0.4  14.638989        -5.8  24.692104  ...        15.959323
# 65         7.0  12.884099         1.6  15.883954  ...        17.088007
#
#     flex2_flex2_mean  flex2_flex2_std  flex3_flex3_mean  flex3_flex3_std  \
# 0              726.6        10.784248             669.8        12.716131
# 1              716.0         8.485281             675.2         5.019960
# 2              723.2         7.293833             686.6        12.054045
# 3              720.8         6.300794             684.8        10.473777
# 4              704.8        10.802777             678.8         9.093954
# ..               ...              ...               ...              ...
# 61             687.8        73.618612             604.2        86.415855
# 62             667.6       106.105137             566.6       106.448579
# 63             663.0        73.773301             567.0        78.380482
# 64             675.0        79.208585             593.2        78.499682
# 65             669.6       109.344867             597.8       114.680862
#
#     flex4_flex4_mean  flex4_flex4_std  flex5_flex5_mean  flex5_flex5_std  \
# 0              676.8         8.729261             703.8        11.945711
# 1              693.4         4.037326             706.8         9.444575
# 2              684.8        11.649034             702.6        13.107250
# 3              684.0        11.832160             716.0         5.958188
# 4              676.8         5.890671             718.8         8.871302
# ..               ...              ...               ...              ...
# 61             614.0        61.575157             622.2       107.931460
# 62             602.2        90.048320             584.2       133.194219
# 63             598.8        53.760580             587.8       108.361432
# 64             616.0        61.676576             611.0        95.749674
# 65             614.8        87.725139             610.2       136.666382
#
#     class_class
# 0             B
# 1             B
# 2             B
# 3             B
# 4             B
# ..          ...
# 61        Miaou
# 62        Miaou
# 63        Miaou
# 64        Miaou
# 65        Miaou
#
# [66 rows x 23 columns]
